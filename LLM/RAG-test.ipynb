# %%
! pip install  langchain~=0.0.352
! pip install  pypdf
! pip install  sentence-transformers==2.2.2
! pip install  huggingface_hub
! pip install  accelerate
! pip install  torch~=2.1.2
! pp install  transformers~=4.36.2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 2.4 MB/s eta 0:00:00a 0:00:01
# ...
# /bin/bash: line 1: pp: command not found

# %%
import pandas as pd
### huggingface dataset with Prompt, Answer pair

# data = load_dataset("arbitropy/kuetdata", split="train")
# data_df = data.to_pandas()

### read csv with Prompt, Answer pair 
data_location = r"Data/Haji_all(03-01-2024)-updated.xlsx"
data_df=pd.read_excel(data_location)


data_df.to_csv('data.txt', sep='\t', index=False)
